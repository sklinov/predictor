# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
money = pd.read_csv("money.csv")

# merge dataframes: money[new_col] = ...

# %%
#money.head(5) # head -> выводит указанное число строк

# %%
# Определение интервалов
# Глубина в прошлое ( дней * недель)
past = 7 * 4
# Глубина в будущее (дней * недель)
future = 7 * 1

# %%
# len -> length -> длина
# Проверка, что датасет подгрузился в нужном объеме
print("В датасете {} строк".format(len(money)))
# Out:
# В датасете 357 строк

# %%
df = list()
values = money["value"]

for i in range(past, len(money) - future):
    part_of_values = values[(i-past):(i+future)]
    df.append(list(part_of_values))

# %%
past_columns = [f"past_{i + 1}" for i in range(past)]
future_columns = [f"future_{i + 1}" for i in range(future)]

# %%
#Заполнение датафрейма данными
df = pd.DataFrame(df, columns=(past_columns + future_columns))

# %%
#df.head(5)

# %%
X = df[past_columns][0:-1] # прошлое + строки за исключением последней
Y = df[future_columns][0:-1] # будущее + строки за исключением последней

# %%
X_test = df[past_columns][-1:]
Y_test = df[future_columns][-1:]

# %%
# Словарь для хранения всех результатов
results = {}

# %%
# Функция добавления к общим результатам, если ошибка меньше 2
def addToResult(name, prediction, norm_error=0):
    if norm_error < 2:
        results[name] = [prediction, norm_error]
    #results[name]['error'] = norm_error

# %%
# Отображение общих результатов
def showOverallResults():
    for method in results:
        lbl = method +':'+ str(round(results[method][1], 4))
        plt.plot(results[method][0], label=lbl) # label <- легенда
    plt.plot(df[future_columns].iloc[-1], label="Факт") 
    plt.legend()

# %%
def showResults(name, df, prediction, Y_test):
    print('Предположение:')
    print(prediction)
    print('Фактические данные:')
    print(Y_test)
    print('Нормализованная ошибка:')
    norm_error = np.linalg.norm(prediction - Y_test)
    print(norm_error)
    plt.plot(prediction, label="Предположение") # label <- легенда
    plt.plot(df[future_columns].iloc[-1], label="Факт") # iloc <- вытаскивает элемент на указанной позиции
    plt.legend() # <- отрисовывает окошко с легендами
    addToResult(name, prediction, norm_error)

# %%
# ------------------
# Линейная регрессия
# ------------------
from sklearn.linear_model import LinearRegression
# Обучение
reg = LinearRegression().fit(X, Y)
# Предположение
prediction = reg.predict(X_test)[0]
# Вывод результатов
showResults('Линейная регрессия',df, prediction, Y_test)
# Out:
# Предположение:
# [64.98736619 64.8617142  64.76306379 64.79960565 64.77087721 64.79504301
#  64.82269863]
# Фактические данные:
#      future_1  future_2  future_3  future_4  future_5  future_6  future_7
# 293   64.7919   64.5158   64.6314   64.4326   64.3187   64.3352   63.9794
# Нормализованная ошибка:
# 1.198734574069572

# %%
# ------------------
# Метод ближаших соседей
# ------------------
from sklearn.neighbors import KNeighborsRegressor
# Параметры
n_of_neighbors = 5 # число соседей
# Обучение
reg = KNeighborsRegressor(n_neighbors=n_of_neighbors).fit(X, Y)
# Предположение
prediction = reg.predict(X_test)[0]
# Вывод результатов
showResults('Ближайшие соседи', df, prediction, Y_test)
# Out:
# Предположение:
# [65.08162 64.9499  64.84278 64.69348 64.58178 64.46282 64.44184]
# Фактические данные:
#      future_1  future_2  future_3  future_4  future_5  future_6  future_7
# 293   64.7919   64.5158   64.6314   64.4326   64.3187   64.3352   63.9794
# Нормализованная ошибка:
# 0.8273264601111254

# %%
# ------------------
# Метод Лассо
# ------------------
from sklearn import linear_model
# Параметры
alpha_param = 0.1 # Альфа-параметр
# Обучение
reg = linear_model.LassoLars(alpha=alpha_param).fit(X, Y).fit(X, Y)
# Предположение
prediction = reg.predict(X_test)[0]
# Вывод результатов
showResults('Лассо', df, prediction, Y_test)
# Out:
# Предположение:
# [64.95343869 64.97172551 64.98910616 65.0065695  65.02399435 65.04479113
#  65.0644628 ]
# Фактические данные:
#      future_1  future_2  future_3  future_4  future_5  future_6  future_7
# 293   64.7919   64.5158   64.6314   64.4326   64.3187   64.3352   63.9794
# Нормализованная ошибка:
# 1.6940125308712017

# %%
# ------------------
# Метод LARS CV
# ------------------
from sklearn import linear_model
from sklearn.datasets import make_regression
# Параметры
cv_param = 5 # Альфа-параметр
# Обучение
X, Y = make_regression(n_samples=50, noise=4.0, random_state=0)
reg = linear_model.LassoLarsCV(cv = cv_param).fit(X, Y)
# Предположение
prediction = reg.predict(X_test)[0]
# Вывод результатов
showResults('Лассо', df, prediction, Y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-7b58bac6e7b9> in <module>
#      10 reg = linear_model.LassoLarsCV(cv = cv_param).fit(X, Y)
#      11 # Предположение
# ---> 12 prediction = reg.predict(X_test)[0]
#      13 # Вывод результатов
#      14 showResults('Лассо', df, prediction, Y_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     219             Returns predicted values.
#     220         """
# --> 221         return self._decision_function(X)
#     222
#     223     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     204         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     205         return safe_sparse_dot(X, self.coef_.T,
# --> 206                                dense_output=True) + self.intercept_
#     207
#     208     def predict(self, X):
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     140         return ret
#     141     else:
# --> 142         return np.dot(a, b)
#     143
#     144
#
# ValueError: shapes (1,84) and (100,) not aligned: 84 (dim 1) != 100 (dim 0)

# %%
# ------------------
# Нейронная сеть / Параметры по-умолчанию
# ------------------
from sklearn import neural_network
# Параметры

# Обучение
reg = neural_network.MLPRegressor()
reg = reg.fit(X, Y)
# Предположение
prediction = reg.predict(X_test)[0]
# Вывод результатов
showResults('НС-default', df, prediction, Y_test)
# Out:
# Предположение:
# [65.1809273  65.20864857 65.37538759 66.04487339 65.96237094 65.43794031
#  65.40127744]
# Фактические данные:
#      future_1  future_2  future_3  future_4  future_5  future_6  future_7
# 293   64.7919   64.5158   64.6314   64.4326   64.3187   64.3352   63.9794
# Нормализованная ошибка:
# 3.1182928313353058
# C:\Users\Sergey\Anaconda3\lib\site-packages\sklearn\neural_network\multilayer_perceptron.py:566: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)

# %%
# ------------------
# Нейронная сеть / Гипотеза 1 - увеличение hls, итераций, алгоритм 
# ------------------
from sklearn import neural_network
# Параметры
hls = 500 # Hidden layer sizes
slvr = 'lbfgs' # Алгоритм -> For small datasets, however, ‘lbfgs’ can converge faster and perform better.
iter = 5000 # Кол-во итераций
# Обучение
reg = neural_network.MLPRegressor(hidden_layer_sizes=hls, solver = slvr, max_iter = iter)
reg = reg.fit(X, Y)
# Предположение
prediction = reg.predict(X_test)[0]
# Вывод результатов
showResults('НС - №1',df, prediction, Y_test)
# Out:
# Предположение:
# [65.1362989  64.98736131 64.8747093  64.91623289 64.74670686 64.68055025
#  64.79864364]
# Фактические данные:
#      future_1  future_2  future_3  future_4  future_5  future_6  future_7
# 293   64.7919   64.5158   64.6314   64.4326   64.3187   64.3352   63.9794
# Нормализованная ошибка:
# 1.2679501810058855

# %%
# ------------------
# Нейронная сеть / Гипотеза 2 - увеличение hls и итераций по сравнению с Гипотезой 1
# ------------------
from sklearn import neural_network
# Параметры
hls = 750 # Hidden layer sizes
slvr = 'lbfgs' # Алгоритм
iter = 10000 # Кол-во итераций
# Обучение
reg = neural_network.MLPRegressor(hidden_layer_sizes=hls, solver = slvr, max_iter = iter)
reg = reg.fit(X, Y)
# Предположение
prediction = reg.predict(X_test)[0]
# Вывод результатов
showResults('НС - №2', df, prediction, Y_test)
# Out:
# Предположение:
# [64.9183352  64.81826478 64.7888503  64.79605002 64.78000146 64.87533045
#  64.93018734]
# Фактические данные:
#      future_1  future_2  future_3  future_4  future_5  future_6  future_7
# 293   64.7919   64.5158   64.6314   64.4326   64.3187   64.3352   63.9794
# Нормализованная ошибка:
# 1.2934039697601953

# %%
# ------------------
# Нейронная сеть / Гипотеза 3 - Гипотеза 2, смена алгоритма на adam
# ------------------
from sklearn import neural_network
# Параметры
hls = 750 # Hidden layer sizes
slvr = 'adam' # Алгоритм
iter = 10000 # Кол-во итераций
# Обучение
reg = neural_network.MLPRegressor(hidden_layer_sizes=hls, solver = slvr, max_iter = iter)
reg = reg.fit(X, Y)
# Предположение
prediction = reg.predict(X_test)[0]
# Вывод результатов
showResults('НС - №3', df, prediction, Y_test)
# Out:
# Предположение:
# [65.1319942  64.79359927 64.91594049 64.54094208 65.24453572 65.12073912
#  64.97983479]
# Фактические данные:
#      future_1  future_2  future_3  future_4  future_5  future_6  future_7
# 293   64.7919   64.5158   64.6314   64.4326   64.3187   64.3352   63.9794
# Нормализованная ошибка:
# 1.6615207030122248

# %%
# ------------------
# Нейронная сеть / Гипотеза 4 - Гипотеза 2, смена алгоритма на sgd
# ------------------
from sklearn import neural_network
# Параметры
hls = 750 # Hidden layer sizes
slvr = 'sgd' # Алгоритм
iter = 10000 # Кол-во итераций
# Обучение
reg = neural_network.MLPRegressor(hidden_layer_sizes=hls, solver = slvr, max_iter = iter)
reg = reg.fit(X, Y)
# Предположение
#prediction = reg.predict(X_test)[0]
#Вывод результатов
showResults('НС - №4',df, prediction, Y_test)
# Out:
# Предположение:
# [65.1319942  64.79359927 64.91594049 64.54094208 65.24453572 65.12073912
#  64.97983479]
# Фактические данные:
#      future_1  future_2  future_3  future_4  future_5  future_6  future_7
# 293   64.7919   64.5158   64.6314   64.4326   64.3187   64.3352   63.9794
# Нормализованная ошибка:
# 1.6615207030122248

# %%
# -----------------------------
# ------ УВЕЛИЧЕНИЕ ИНТЕРВАЛА ОБУЧЕНИЯ В 2 РАЗА
# Определение интервалов
# Глубина в прошлое ( дней * недель)
past2 = 7 * 12
# Глубина в будущее (дней * недель)
future = 7 * 1

# %%
df = list()
values = money["value"]

for i in range(past2, len(money) - future):
    part_of_values = values[(i-past2):(i+future)]
    df.append(list(part_of_values))

# %%
past_columns = [f"past_{i + 1}" for i in range(past2)]
future_columns = [f"future_{i + 1}" for i in range(future)]

# %%
#Заполнение датафрейма данными
df = pd.DataFrame(df, columns=(past_columns + future_columns))

# %%
#df.head(5)

# %%
X = df[past_columns][0:-1] # прошлое + строки за исключением последней
Y = df[future_columns][0:-1] # будущее + строки за исключением последней

# %%
X_test = df[past_columns][-1:]
Y_test = df[future_columns][-1:]

# %%
# ------------------
# Нейронная сеть / Гипотеза 5 - увеличение hls и итераций по сравнению с Гипотезой 2
# ------------------
from sklearn import neural_network
# Параметры
hls = 1000 # Hidden layer sizes
slvr = 'lbfgs' # Алгоритм
iter = 30000 # Кол-во итераций
# Обучение
reg = neural_network.MLPRegressor(hidden_layer_sizes=hls, solver = slvr, max_iter = iter)
reg = reg.fit(X, Y)
# Предположение
prediction = reg.predict(X_test)[0]
# Вывод результатов
showResults('НС-увел.данных',df, prediction, Y_test)
# Out:
# Предположение:
# [64.9636219  64.57072186 64.4020386  64.2728055  63.85250168 63.48473446
#  63.73616217]
# Фактические данные:
#      future_1  future_2  future_3  future_4  future_5  future_6  future_7
# 265   64.7919   64.5158   64.6314   64.4326   64.3187   64.3352   63.9794
# Нормализованная ошибка:
# 1.0537755457004048

# %%
# Домашнее задание
# датасет будем присылать

# https://scikit-learn.org/stable/modules/generated/sklearn.neural_network.MLPRegressor.html
# 1) настроить алгоритм, чтобы суммарная ошибка была меньше 0.780593173587177
# 2) добавить свой алгоритм из scikit-learn
# 3) pdf/html -> в опросник

# все должно работать
# все пункты должны быть выполнены

# оформление
# комментарии
# выводы

# дедлайн: 12:00 МСК 14.08.2019

# %%
showOverallResults()
